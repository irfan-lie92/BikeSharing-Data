# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Data
# - Nama: IRFAN ALI
# - Email: ir.vanaly@gmail.com
# - Id Dicoding: irfanlie92

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada Season/Musim apa Bike Rentals lebih banyak beraktivitas?
# - Pada jam berapa rata-rata Aktivitas Bike Rentals per-jam dan per-hari dalam seminggu?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data wrangling
# ## gathering data

# %% [markdown]
# ### tabel `day`

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### tabel `hour`

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ## Assessing data
# ### menilai data `day_df`

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ### menilai data `hour_df`

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ",hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ## Cleaning data
# ### membersihkan data `day_df`

# %% [markdown]
# #### memperbaiki type data

# %%
day_df["dteday"] = pd.to_datetime(day_df["dteday"])

# %%
day_df.fillna(day_df.mean())
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
# 730      731 2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# #### menghapus duplikat `day_df`

# %%
day_df.describe(include='all')
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
day_df.drop_duplicates()
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
# 730      731 2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
day_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### membersihkan data `hour_df`

# %% [markdown]
# #### memperbaiki type data

# %%
hour_df["dteday"] = pd.to_datetime(hour_df["dteday"])

# %%
hour_df.fillna(hour_df.mean())
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# #### menghapus duplikat `hour_df`

# %%
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
hour_df.drop_duplicates()
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
hour_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Exploratory data `day_df`

# %%
day_df.sample(5)
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 530      531 2012-06-14       2   1     6        0        4           1
# 217      218 2011-08-06       3   0     8        0        6           0
# 683      684 2012-11-14       4   1    11        0        3           1
# 320      321 2011-11-17       4   0    11        0        4           1
# 543      544 2012-06-27       3   1     6        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 530           1  0.648333  0.624383  0.569583   0.253733    1180        6183
# 217           2  0.716667  0.676154  0.755000   0.228250    1521        2773
# 683           1  0.289167  0.281563  0.552083   0.199625     373        5122
# 320           2  0.341667  0.323221  0.575833   0.305362     139        2914
# 543           1  0.697500  0.640792  0.360000   0.271775    1077        6258
#
#       cnt
# 530  7363
# 217  4294
# 683  5495
# 320  3053
# 543  7335

# %%
day_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>,
#         <Axes: title={'center': 'workingday'}>],
#        [<Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'hum'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>,
#         <Axes: title={'center': 'cnt'}>]], dtype=object)

# %%
day_df.describe()
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
day_df.instant.is_unique
# Out:
# True

# %%
day_df.instant.duplicated
# Out:
# <bound method Series.duplicated of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 726    727
# 727    728
# 728    729
# 729    730
# 730    731
# Name: instant, Length: 731, dtype: int64>

# %% [markdown]
# #### season : season (1:springer, 2:summer, 3:fall, 4:winter) - readme.md

# %%
day_df.groupby(by="season").agg({
    "instant": "nunique",
    "cnt": ["max", "min", "mean", "std"],
})
# Out:
#        instant   cnt
#        nunique   max   min         mean          std
# season
# 1          181  7836   431  2604.132597  1399.942119
# 2          184  8362   795  4992.331522  1695.977235
# 3          188  8714  1115  5644.303191  1459.800381
# 4          178  8555    22  4728.162921  1699.615261

# %% [markdown]
# ### Exploratory data `hour_df`

# %%
hour_df.sample(5)
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 843        844 2011-02-07       1   0     2  14        0        1           1
# 2156      2157 2011-04-04       2   0     4  17        0        1           1
# 10192    10193 2012-03-05       1   1     3  18        0        1           1
# 2619      2620 2011-04-24       2   0     4   1        0        0           0
# 9234      9235 2012-01-25       1   1     1  16        0        3           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 843             2  0.36  0.3636  0.57     0.0896       8          52   60
# 2156            1  0.74  0.6515  0.23     0.6119      83         283  366
# 10192           3  0.28  0.2273  0.55     0.6567      12         363  375
# 2619            1  0.50  0.4848  0.88     0.1940      14          40   54
# 9234            1  0.34  0.3333  0.53     0.1642      29         217  246

# %%
hour_df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>, <Axes: title={'center': 'hr'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>],
#        [<Axes: title={'center': 'workingday'}>,
#         <Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>],
#        [<Axes: title={'center': 'hum'}>,
#         <Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>],
#        [<Axes: title={'center': 'cnt'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hour_df.describe()
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
hour_df.instant.is_unique
# Out:
# True

# %%
hour_df.instant.duplicated
# Out:
# <bound method Series.duplicated of 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 17374    17375
# 17375    17376
# 17376    17377
# 17377    17378
# 17378    17379
# Name: instant, Length: 17379, dtype: int64>

# %% [markdown]
# #### weekday : day of the week - readme.md

# %%
day_df.groupby(by="weekday").agg({
    "instant": "nunique",
    "cnt": ["max", "min", "mean", "std"],
})
# Out:
#         instant   cnt
#         nunique   max   min         mean          std
# weekday
# 0           105  8227   605  4228.828571  1872.496629
# 1           105  7525    22  4338.123810  1793.074013
# 2           104  7767   683  4510.663462  1826.911642
# 3           104  8173   441  4548.538462  2038.095884
# 4           104  7804   431  4667.259615  1939.433317
# 5           104  8362  1167  4690.288462  1874.624870
# 6           105  8714   627  4550.542857  2196.693009

# %% [markdown]
# ### Explore

# %%
day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
analisadata_df = pd.merge(day_df, hour_df, on='instant')

# %%
analisadata_df.head()
# Out:
#    instant   dteday_x  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 0        1 2011-01-01         1     0       1          0          6
# 1        2 2011-01-02         1     0       1          0          0
# 2        3 2011-01-03         1     0       1          0          1
# 3        4 2011-01-04         1     0       1          0          2
# 4        5 2011-01-05         1     0       1          0          3
#
#    workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 0             0             2  0.344167  ...          6             0
# 1             0             2  0.363478  ...          6             0
# 2             1             1  0.196364  ...          6             0
# 3             1             1  0.200000  ...          6             0
# 4             1             1  0.226957  ...          6             0
#
#    weathersit_y  temp_y  atemp_y  hum_y windspeed_y  casual_y  registered_y  \
# ...

# %%
analisadata_df.to_csv("analisadata.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Pada Season/Musim apa Bike Rentals lebih banyak beraktivitas?

# %%
analisadata_df.sample(5)
# Out:
#      instant   dteday_x  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 367      368 2012-01-03         1     1       1          0          2
# 325      326 2011-11-22         4     0      11          0          2
# 604      605 2012-08-27         3     1       8          0          1
# 45        46 2011-02-15         1     0       2          0          2
# 85        86 2011-03-27         2     0       3          0          0
#
#      workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 367             1             1  0.150000  ...          0             0
# 325             1             3  0.416667  ...          6             0
# 604             1             1  0.703333  ...          5             1
# 45              1             1  0.266087  ...          0             0
# 85              0             2  0.253043  ...          2             1
#
#      weathersit_y  temp_y  atemp_y  hum_y windspeed_y  casual_y  registered_y  \
# ...

# %%
analisadata_df.head()
# Out:
#    instant   dteday_x  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 0        1 2011-01-01         1     0       1          0          6
# 1        2 2011-01-02         1     0       1          0          0
# 2        3 2011-01-03         1     0       1          0          1
# 3        4 2011-01-04         1     0       1          0          2
# 4        5 2011-01-05         1     0       1          0          3
#
#    workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 0             0             2  0.344167  ...          6             0
# 1             0             2  0.363478  ...          6             0
# 2             1             1  0.196364  ...          6             0
# 3             1             1  0.200000  ...          6             0
# 4             1             1  0.226957  ...          6             0
#
#    weathersit_y  temp_y  atemp_y  hum_y windspeed_y  casual_y  registered_y  \
# ...

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
weather_rentals = analisadata_df.groupby('season_x')['cnt_y'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(data=weather_rentals, x='season_x', y='cnt_y')
plt.xlabel('Season/musim')
plt.ylabel('Rata-rata Pengguna')
plt.xticks(range(4),['spring', 'summer', 'fall', 'winter'])
plt.title('Rata-rata Bike Rentals berdasarkan season/musim')
plt.show()

# %% [markdown]
# Hasil : terlihat pada grafik data bahwa aktivitas Bike Rentals terbanyak pada Season/musim `summer`.

# %% [markdown]
# ### Pertanyaan 2: Pada jam berapa rata-rata Aktivitas Bike Rentals per-jam dan per-hari dalam seminggu?

# %%
analisadata_df.head()
# Out:
#    instant   dteday_x  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 0        1 2011-01-01         1     0       1          0          6
# 1        2 2011-01-02         1     0       1          0          0
# 2        3 2011-01-03         1     0       1          0          1
# 3        4 2011-01-04         1     0       1          0          2
# 4        5 2011-01-05         1     0       1          0          3
#
#    workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 0             0             2  0.344167  ...          6             0
# 1             0             2  0.363478  ...          6             0
# 2             1             1  0.196364  ...          6             0
# 3             1             1  0.200000  ...          6             0
# 4             1             1  0.226957  ...          6             0
#
#    weathersit_y  temp_y  atemp_y  hum_y windspeed_y  casual_y  registered_y  \
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=analisadata_df, x='hr', y='cnt_y')
plt.xlabel('jam dalam sehari')
plt.ylabel('Pengguna')
plt.title('Rata-rata Bike Rentals setiap jam')
plt.show()

# %% [markdown]
# Hasil : terlihat pada grafik data bahwa aktivitas Bike Rentals terbanyak pada Jam `17.00`.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
plt.figure(figsize=(12, 6))
sns.barplot(data=analisadata_df, x='weekday_x', y='cnt_y')
plt.xlabel('Hari dalam seminggu')
plt.ylabel('pengguna')
plt.title('Rata-rata Bike Rentals setiap hari')
plt.xticks(range(7), ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.show()

# %% [markdown]
# Hasil : terlihat pada grafik data bahwa aktivitas Bike Rentals terbanyak pada Hari `Tuesday`.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Pada Season/Musim apa pengguna Bike Sharing lebih banyak beraktivitas?
# ##### dapat di lihat bahwa aktivitas Bike Rentals terbanyak pada season/musim `summer`.
#
# - Pada jam berapa rata-rata Aktivitas Bike Rentals per-jam dan per-hari dalam seminggu?
# ##### dari data tersebut aktivitas Bike Rentals terbanyak pada jam `17.00`.
# ##### dan aktivitas Bike Rentals terbanyak pada hari `Tuesday`.

# %% [markdown]
# Sebagai Catatan data di atas bersumber dari Capital Bikeshare system, Washington D.C pada tahun 2011 and 2012. Refrensi data diambil dari : http://capitalbikeshare.com/system-data
